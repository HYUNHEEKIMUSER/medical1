# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic' #한글설정
matplotlib.rcParams['font.size']= 15 #글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

x = ['han','kim','hong']
y = [20,40,80]
plt.plot(x,y)
plt.title('막대그래프')
# x,y축의 설명
plt.xlabel('국어',loc = 'right')  #left center right
plt.ylabel('이름',loc='top')  #top center bottom
# Out:
# Text(0, 1, '이름')
