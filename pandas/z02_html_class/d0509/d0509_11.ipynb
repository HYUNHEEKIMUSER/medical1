# %%
import pandas as pd
df = pd.read_excel('score.xlsx',index_col = '지원번호')
df.sort_index(ascending=True,inplace=True)

# %%
# 컬럼추가는 없는 컬럼에 데이터를 입력하면 추가가 됨
df['합계'] = df['국어'] +df['영어'] +df['수학']+df['과학']+df['사회']

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기   합계
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python  455
# 2번    강태원  구로고  184   40   35   50  55  25        Java  205
# 3번    강호림  구로고  168   80   75   70  80  75  javascript  380
# 4번    김수진  구로고  187   40   60   70  75  80         NaN  325
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN   90
# 6번    박동현  단지고  202   80  100   95  85  80           C  440
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON  240
# 8번    승근열  단지고  190  100   85   90  95  95          c#  465

# %%
df['국어'] = df['국어']  - 10

# %%
# 학교이름 수정
df['학교'].replace({'구로고등학교등학교':'디지털고',"단지고등학교등학교":"영등포고"},inplace=True)
df
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_20764\546057566.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['학교'].replace({'구로고등학교등학교':'디지털고',"단지고등학교등학교":"영등포고"},inplace=True)
#        이름   학교    키  국어   영어   수학  과학  사회        SW특기   합계
# 지원번호
# 1번    강나래  구로고  197  80   85  100  95  85      Python  455
# 2번    강태원  구로고  184  30   35   50  55  25        Java  205
# 3번    강호림  구로고  168  70   75   70  80  75  javascript  380
# 4번    김수진  구로고  187  30   60   70  75  80         NaN  325
# 5번    김재욱  구로고  188   5   20   10  35  10         NaN   90
# 6번    박동현  단지고  202  70  100   95  85  80           C  440
# 7번    박혜정  단지고  188  45   65   45  40  35      PYTHON  240
# 8번    승근열  단지고  190  90   85   90  95  95          c#  465

# %%
# 컬럼 전체 수정
df['SW특기'] = df['SW특기'].str.upper()
df
# 컬럼부분 삭제
df.drop(columns='사회',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 5
#       3 df
#       4 # 컬럼부분 삭제
# ----> 5 df.drop(columns='사회',inplace=True)
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['사회'] not found in axis"

# %%
# 컬럼부분 삭제
import pandas as pd
df = pd.read_excel('score.xlsx',index_col = '지원번호')
df.sort_index(ascending=True,inplace=True) 
df.drop(columns=['국어','과학'],inplace=True)
df
df['학교'].value_counts()
# Out:
# 학교
# 구로고    5
# 단지고    3
# Name: count, dtype: int64

# %%
for df in df.values:
    print(df)
# Out:
# ['강나래' '구로고' 197 85 100 85 'Python']
# ['강태원' '구로고' 184 35 50 25 'Java']
# ['강호림' '구로고' 168 75 70 75 'javascript']
# ['김수진' '구로고' 187 60 70 80 nan]
# ['김재욱' '구로고' 188 20 10 10 nan]
# ['박동현' '단지고' 202 100 95 80 'C']
# ['박혜정' '단지고' 188 65 45 35 'PYTHON']
# ['승근열' '단지고' 190 85 90 95 'c#']
