# %%
import pandas as pd
df = pd.read_csv('chipotle.tsv',sep='\t')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# 기초 데이터 탐색
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.describe()
# Out:
#           quantity
# count  4622.000000
# mean      1.075725
# std       0.410186
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max      15.000000

# %%
df['order_id'] = df['order_id'].astype(str)

# %%
df
# Out:
#      order_id  quantity                              item_name  \
# 0           1         1           Chips and Fresh Tomato Salsa
# 1           1         1                                   Izze
# 2           1         1                       Nantucket Nectar
# 3           1         1  Chips and Tomatillo-Green Chili Salsa
# 4           2         2                           Chicken Bowl
# ...       ...       ...                                    ...
# 4617     1833         1                          Steak Burrito
# 4618     1833         1                          Steak Burrito
# 4619     1834         1                     Chicken Salad Bowl
# 4620     1834         1                     Chicken Salad Bowl
# 4621     1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# ...

# %%
import pandas as pd
df = pd.read_csv('chipotle.tsv',sep='\t')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# 주문 당 평균 계산금액을 출력하시오.
df['item_price']=df['item_price'].replace("$","").astype(float)
# df.groupby('order_id')['item_price'].mean()
df
df.groupby('order_id')['item_price'].sum().mean()
df_sum = df.groupby('order_id').sum()
df_sum[df_sum['item_price']>=10]
# Out:
#           quantity                                          item_name  \
# order_id
# 1                4  Chips and Fresh Tomato SalsaIzzeNantucket Nect...
# 2                2                                       Chicken Bowl
# 3                2                          Chicken BowlSide of Chips
# 4                2                      Steak BurritoSteak Soft Tacos
# 5                2                   Steak BurritoChips and Guacamole
# ...            ...                                                ...
# 1830             2                        Steak BurritoVeggie Burrito
# 1831             3                    Carnitas BowlChipsBottled Water
# 1832             2              Chicken Soft TacosChips and Guacamole
# 1833             2                         Steak BurritoSteak Burrito
# 1834             3  Chicken Salad BowlChicken Salad BowlChicken Sa...
#
#                                          choice_description  item_price
# order_id
# ...

# %%
# 한 주문에 10달러 이상 사용한 주문번호를 출력하시오.
df_sum = df.groupby('order_id').sum()
df_sum[df_sum['item_price']>=10].sort_values('item_price',ascending=False).head()['item_price']
# Out:
# order_id
# 926     205.25
# 1443    160.74
# 1483    139.00
# 691     118.25
# 1786    114.30
# Name: item_price, dtype: float64

# %%
#item당 주문갯수 출력/ 주문갯수, 주문갯수의 합
df.groupby('item_name')['order_id'].count()
df[df['item_name'] == '6 Pack Soft Drink '].sort_values('quantity',ascending=False)
df.groupby('item_name')['order_id'].count().head(10)
# Out:
# item_name
# 6 Pack Soft Drink     4622
# Name: order_id, dtype: int64

# %%
# 각 아이템의 가격 구하시오
# 주문 1개이면서 item_name 최저가격인 것을 출력하시오.
import pandas as pd
df = pd.read_csv('chipotle.tsv',sep='\t')
df.groupby('item_name').count()

qu_df = df[df['quantity'] == 1]
groupby_df = qu_df.groupby('item_name').min()
groupby_df.sort_values('item_price')
# Out:
#                                        order_id  quantity  \
# item_name
# Canned Soda                                  14         1
# Bottled Water                                17         1
# Canned Soft Drink                           114         1
# Side of Chips                                 3         1
# Chips                                        19         1
# Chicken Bowl                                  3         1
# Chicken Burrito                               8         1
# Chicken Soft Tacos                            6         1
# Veggie Burrito                               26         1
# Veggie Bowl                                  28         1
# Chicken Salad                               109         1
# Chicken Crispy Tacos                          6         1
# Barbacoa Burrito                             11         1
# Steak Burrito                                 4         1
# Carnitas Bowl                                17         1
# ...

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# 가장 비싼 주문에서 item이 총 몇 개 주문되었는 지 출력
# 가장 높은 금액으로 주문한 주문번호, 수량, 금액을 출력
# 주문 중 가장 높은 금액의 수량과 금액을 출력

# df
# df['item_price']=df['item_price'].replace("$","").astype(float)
# high=df['item_price'].max()
# high[high['item_price'],['order_id','quantity','item_price']]

df.groupby('order_id')[['order_id','quantity','item_price']].sum().sort_values('item_price',ascending=False)
# Out:
#           order_id  quantity  item_price
# order_id
# 113            226         2       10.08
# 1122          2244         2       10.08
# 100            200         2       10.08
# 1494          2988         2       10.08
# 1475          2950         2       10.08
# ...            ...       ...         ...
# 1786         19646        20      114.30
# 691           7601        11      118.25
# 1483         20762        14      139.00
# 1443         10101        35      160.74
# 926          21298        23      205.25
#
# [1834 rows x 3 columns]

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# chicken bowl을 한 주문에 2개 이상 주문한 횟수가 몇 번인지 출력
chicken= df[df['item_name'] == 'Chicken Bowl']
len(chicken[chicken['quantity'] >=2])

# chicken bowl의 총 매출액
chicken_sum = chicken['item_price'].sum()
all_sum = df['item_price'].sum()
# chicken bowl은 총매출액의 몇 %가 되는 지 출력
chicken_sum/all_sum*100
# Out:
# 21.283176657731442

# %%
# Out:
# 34500.16
