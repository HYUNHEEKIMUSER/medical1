# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #윈도우사용자
# matplotlib.rcParams['font.family'] = 'AppleGothic Gothic' 맥사용자
matplotlib.rcParams['font.size'] = '10'  #글자크기
matplotlib.rcParams['axes.unicode_minus'] = False #마이너스 표시 해결

# %%
import pandas as pd
df = pd.read_excel('score.xlsx',index_col='지원번호')
df.head(3)
# Out:
#        이름   학교  학년    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고   3  197  90  85  100  95  85      Python
# 2번    강태원  구로고   3  184  40  35   50  55  25        Java
# 3번    강호림  구로고   2  168  80  75   70  80  75  javascript

# %%
x=df.head(5)['이름']

# %%
x=df.head(5)['이름']
y=df.head(5)['국어']
y2=df.head(5)['영어']
y3=df.head(5)['수학']

# %%
plt.plot(x,y,label='국어',marker='D')
plt.plot(x,y2,label='영어',marker='o',ls='--')
plt.plot(x,y3,label='수학',marker='s',ls='-.')
for i, txt in enumerate(y3):
    plt.text(x[i],y3[i]+0.9,txt,ha='center')
plt.legend(loc='upper center',ncol=3)
plt.show()
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_10276\2736298206.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x[i],y3[i]+0.9,txt,ha='center')

# %%
plt.bar(x,y,label='국어',marker='D')
plt.bar(x,y2,label='영어',marker='o',ls='--')
plt.bar(x,y3,label='수학',marker='s',ls='-.')
for i, txt in enumerate(y3):
    plt.text(x[i],y3[i]+0.9,txt,ha='center')
plt.legend(loc='upper center',ncol=3)
plt.show()
