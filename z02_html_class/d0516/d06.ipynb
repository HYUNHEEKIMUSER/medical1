# %%
import matplotlib.pyplot as plt
# 한글설정
import matplotlib 
import pandas as pd
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #윈도우사용자
# matplotlib.rcParams['font.family'] = 'AppleGothic Gothic' 맥사용자
matplotlib.rcParams['font.size'] = '15'  #글자크기
matplotlib.rcParams['axes.unicode_minus'] = False #마이너스 표시 해결

# %%
df = pd.read_excel('20230104_연령별인구현황.xlsx',skiprows=3,index_col='행정기관',thousands=',',usecols='B,E:Y')
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
cols=df.columns

# %%
x=df.columns.values

# %%
y=df.iloc[0,0:21].values

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 21 artists>

# %%
df = pd.read_excel('20230104_연령별인구현황.xlsx',skiprows=3,index_col='행정기관',thousands=',',usecols='B,AB:AV')
x1 = df.columns.values
y1 = df.iloc[0,0:21].values
plt.barh(x1,y1)
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# <BarContainer object of 21 artists>

# %%
a = pd.read_excel('20230104_연령별인구현황.xlsx')
a
a.iloc[0]
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ※ 매월 말일자 통계 현황         NaN
# Unnamed: 1             NaN
# Unnamed: 2        2023년01월
# Unnamed: 3             NaN
# Unnamed: 4             NaN
#                     ...
# Unnamed: 181           NaN
# Unnamed: 182           NaN
# Unnamed: 183           NaN
# Unnamed: 184           NaN
# Unnamed: 185           NaN
# Name: 0, Length: 186, dtype: object

# %%
df = pd.read_excel('20230104_연령별인구현황.xlsx',index_col='행정기관',thousands=',',usecols='B,E:Y')
df2 = pd.read_excel('20230104_연령별인구현황.xlsx',index_col='행정기관',thousands=',',usecols='B,AB:AV')
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df = pd.read_excel('20230104_연령별인구현황.xlsx',index_col='행정기관',thousands=',',usecols='B,E:Y')
#       2 df2 = pd.read_excel('20230104_연령별인구현황.xlsx',index_col='행정기관',thousands=',',usecols='B,AB:AV')
#       3 df2
#
# File c:\Python312\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# ...

# %%
df2.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
# 남여데이터 컬럼명을 통일
df2.columns=df.columns

# %%
# 가로막대 그래프
plt.barh(df.columns,df.iloc[0]//1000)
plt.barh(df2.columns,-df2.iloc[0]//1000)
# Out:
# <BarContainer object of 21 artists>

# %% [markdown]
# ### 1월 2월 3월 4월 합산을 해서 가로막대 그래프를 출력하시오.

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of              0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         691045  1020598  1144645  1134811  1402493  1642682  1579871
# 서울특별시      109390   154162   176096   189009   304285   418972   379071
# 부산광역시       39356    60582    65329    64001    88307   102363    96466
# 대구광역시       29517    47039    51645    53188    65933    71873    65115
# 인천광역시       41505    59985    66881    65904    80089    99535    98125
# 광주광역시       20633    31124    35819    36800    46059    48645    42140
# 대전광역시       20120    29266    33099    34644    45960    50861    45012
# 울산광역시       16024    25063    27185    25355    25988    29820    30751
# 세종특별자치시      9323    13207    13629    10886     8405    10259    14210
# 경기도        206896   298872   329545   318130   378103   440729   443662
# 강원도         19847    26739    31256    32170    37089    37292    36592
# ...

# %%
# x = ['2023년 1월']
# y = pd.read_excel('20230104_연령별인구현황.xlsx',thousands=',',usecols='B,AB:AV')
# y.columns
# x[0]
# plt.barh(x[0],y.columns)
# x1 = ['2023년 2월']
# y1 = pd.read_excel('20230104_연령별인구현황.xlsx',thousands=',',usecols='B,VB:CP')
# y1.columns
# x1[0]
# plt.barh(x1[0],y1.columns)
x = ['2023년 1월']
y = df2.iloc[0,:3].sum()
y2 = df2.iloc[0,3:13].sum()
y3 = df2.iloc[0,13:46].sum()
plt.barh(x,y)
plt.barh(x,y2)
plt.barh(x,y3)
x = ['2023년 2월']
y = df2.iloc[0,46:47].sum()
y2 = df2.iloc[0,47:60].sum()
y3 = df2.iloc[0,61:74].sum()
plt.barh(x,y)
plt.barh(x,y2)
plt.barh(x,y3)
x = ['2023년 3월']
y = df2.iloc[0,74:87].sum()
y2 = df2.iloc[0,87:100].sum()
y3 = df2.iloc[0,100:113].sum()
plt.barh(x,y)
plt.barh(x,y2)
plt.barh(x,y3)
x = ['2023년 4월']
y = df2.iloc[0,113:126].sum()
y2 = df2.iloc[0,126:139].sum()
y3 = df2.iloc[0,139:].sum()
plt.barh(x,y)
plt.barh(x,y2)
plt.barh(x,y3)
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# <BarContainer object of 1 artists>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 group = df.groupby('전국')['5~9세.1'].mean()
#       2 print(group)
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...
